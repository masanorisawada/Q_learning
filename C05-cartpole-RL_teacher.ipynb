# %% [markdown]
# # ライブラリのインポート

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %% [markdown]
# # 動画に保存する関数

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

def save_as_gif(frames):
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0), dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)

    anim.save('RL-cartpole.mp4')
    display(display_animation(anim, default_mode='loop'))

# %%
# 学習に使う変数を整理
ENV = 'CartPole-v0'
# 状態をどれくらいの値で分割して離散値とするか
NUM_DIGITIZED = 6
# 報酬割引率
GAMMA = 0.99
# 学習率
ETA = 0.5
# 1試行（1エピソード）の最大ステップ数
MAX_STEP = 200
# 最大試行回数（エピソード数）
NUM_EPISODES = 1000

# %%
# エージェントクラス
class Agent:

    # 初期化関数で行動数と行動の種類を受けとり，行動を決定するためのBrainクラスを生成する
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)

    # Q関数を更新
    def update_q_function(self, observation, action, reward, observation_next):
        self.brain.update_Q_table(observation, action, reward, observation_next)

    # 行動の決定
    def get_action(self, observation, step):
        return self.brain.decide_action(observation, step)


# エージェントが行う行動を与えられた状態によって判断する部分（強化学習を行う部分）
class Brain:

    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions
        # Qテーブルを作成。行数は状態を分割数^（4変数）にデジタル変換した値、列数は行動数を示す
        self.q_table = np.random.uniform(low=0, high=1, size=(NUM_DIGITIZED**num_states, num_actions))


    # カート情報を離散化するための閾値を求める
    def bins(self, clip_min, clip_max, num):
        return np.linspace(clip_min, clip_max, num + 1)[1:-1]

    # カートの情報を離散化する
    def digitize_state(self, observation):
        '''観測したobservation状態を、離散値に変換する'''
        cart_pos, cart_v, pole_angle, pole_v = observation
        digitized = [
            np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIGITIZED)),
            np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIGITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIGITIZED)),
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIGITIZED))
        ]
        return sum([x * (NUM_DIGITIZED**i) for i, x in enumerate(digitized)])

    # QテーブルをQ学習により更新
    def update_Q_table(self, observation, action, reward, observation_next):
        # 状態を離散化
        state = self.digitize_state(observation)
        state_next = self.digitize_state(observation_next)
        
        # Qテーブルの最大値を取得
        max_Q_next = max(self.q_table[state_next][:])
        
        # Qテーブルの更新
        self.q_table[state, action] = self.q_table[state, action] + ETA * (reward + GAMMA * max_Q_next - self.q_table[state, action])


    # ε-greedy法で徐々に最適行動を行うようにする
    def decide_action(self, observation, episode):
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode + 1))
        
        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)
               
        return action

# %%
## CartPoleを実行する環境
class Environment:

    def __init__(self):
        self.env = gym.make(ENV)  # 実行する課題を設定
        num_states = self.env.observation_space.shape[0]  # 課題の状態を取得
        num_actions = self.env.action_space.n  # CartPoleの行動を取得
        self.agent = Agent(num_states, num_actions)  # 環境内で行動するAgentを生成

    ## 実行関数
    def run(self):

        complete_episodes = 0  # 195step以上連続で立ち続けた試行数
        is_episode_final = False  # 最終試行フラグ
        frames = []  # 動画用に画像を格納する変数

        # 全エピソードループ
        for episode in range(NUM_EPISODES):
            # エピソード毎に環境を初期化
            observation = self.env.reset()
            
            for step in range(MAX_STEP):
                if is_episode_final:
                    frames.append(self.env.render(mode='rgb_array'))
                    
                # 最初の行動を決める
                action = self.agent.get_action(observation, episode)
                
                # 最初の行動から次の状態を求める
                observation_next, _, done, _ = self.env.step(action)
                
                # 報酬を与える
                if done:
                    if step < 195:
                        # こけたら報酬-1
                        reward = -1
                        complete_episodes = 0
                    else:
                        # 立ったまま終了した場合は報酬1
                        reward = 1
                        complete_episodes += 1
                else:
                    # 途中の報酬は0
                    reward = 0
                    
                self.agent.update_q_function(observation, action, reward, observation_next)
                
                # 状態を次の状態に更新
                observation = observation_next
                    
                # エピソード終了時    
                if done:
                    print('{0}エピソード: {1}ステップで終了'.format(episode, step + 1))
                    break
            
            # 最終エピソードの場合は動画を保存
            if is_episode_final:
                save_as_gif(frames)
                break
            
            # 10回連続で成功したら、次のエピソードで終わりにする
            if complete_episodes >= 10:
                print('10回連続成功')
                is_episode_final = True
                
            
                



    # 最終試行では動画を保存と描画


    # 10エピソード連続成功なら次の試行を描画を行う最終試行とする

# %%
# main
cartpole_env = Environment()
cartpole_env.run()
# Out:
# 0エピソード: 24ステップで終了
# 1エピソード: 15ステップで終了
# 2エピソード: 10ステップで終了
# 3エピソード: 11ステップで終了
# 4エピソード: 11ステップで終了
# 5エピソード: 10ステップで終了
# 6エピソード: 17ステップで終了
# 7エピソード: 16ステップで終了
# 8エピソード: 11ステップで終了
# 9エピソード: 15ステップで終了
# 10エピソード: 10ステップで終了
# 11エピソード: 15ステップで終了
# 12エピソード: 43ステップで終了
# 13エピソード: 56ステップで終了
# 14エピソード: 43ステップで終了
# 15エピソード: 26ステップで終了
# 16エピソード: 10ステップで終了
# 17エピソード: 57ステップで終了
# 18エピソード: 60ステップで終了
# 19エピソード: 45ステップで終了
# 20エピソード: 39ステップで終了
# 21エピソード: 23ステップで終了
# 22エピソード: 35ステップで終了
# 23エピソード: 43ステップで終了
# 24エピソード: 77ステップで終了
# 25エピソード: 10ステップで終了
# 26エピソード: 8ステップで終了
# 27エピソード: 26ステップで終了
# 28エピソード: 49ステップで終了
# 29エピソード: 20ステップで終了
# 30エピソード: 10ステップで終了
# 31エピソード: 21ステップで終了
# 32エピソード: 10ステップで終了
# 33エピソード: 20ステップで終了
# 34エピソード: 41ステップで終了
# 35エピソード: 26ステップで終了
# 36エピソード: 40ステップで終了
# 37エピソード: 43ステップで終了
# 38エピソード: 31ステップで終了
# 39エピソード: 36ステップで終了
# 40エピソード: 17ステップで終了
# 41エピソード: 10ステップで終了
# 42エピソード: 16ステップで終了
# 43エピソード: 38ステップで終了
# 44エピソード: 28ステップで終了
# 45エピソード: 80ステップで終了
# 46エピソード: 14ステップで終了
# 47エピソード: 20ステップで終了
# 48エピソード: 25ステップで終了
# 49エピソード: 111ステップで終了
# 50エピソード: 85ステップで終了
# 51エピソード: 23ステップで終了
# 52エピソード: 41ステップで終了
# 53エピソード: 47ステップで終了
# 54エピソード: 153ステップで終了
# 55エピソード: 70ステップで終了
# 56エピソード: 111ステップで終了
# 57エピソード: 51ステップで終了
# 58エピソード: 138ステップで終了
# 59エピソード: 133ステップで終了
# 60エピソード: 165ステップで終了
# 61エピソード: 50ステップで終了
# 62エピソード: 61ステップで終了
# 63エピソード: 31ステップで終了
# 64エピソード: 63ステップで終了
# 65エピソード: 33ステップで終了
# 66エピソード: 92ステップで終了
# 67エピソード: 49ステップで終了
# 68エピソード: 103ステップで終了
# 69エピソード: 42ステップで終了
# 70エピソード: 49ステップで終了
# 71エピソード: 143ステップで終了
# 72エピソード: 197ステップで終了
# 73エピソード: 126ステップで終了
# 74エピソード: 200ステップで終了
# 75エピソード: 35ステップで終了
# 76エピソード: 44ステップで終了
# 77エピソード: 12ステップで終了
# 78エピソード: 21ステップで終了
# 79エピソード: 139ステップで終了
# 80エピソード: 25ステップで終了
# 81エピソード: 137ステップで終了
# 82エピソード: 12ステップで終了
# 83エピソード: 56ステップで終了
# 84エピソード: 14ステップで終了
# 85エピソード: 200ステップで終了
# 86エピソード: 173ステップで終了
# 87エピソード: 132ステップで終了
# 88エピソード: 175ステップで終了
# 89エピソード: 105ステップで終了
# 90エピソード: 169ステップで終了
# 91エピソード: 192ステップで終了
# 92エピソード: 170ステップで終了
# 93エピソード: 142ステップで終了
# 94エピソード: 200ステップで終了
# 95エピソード: 200ステップで終了
# 96エピソード: 100ステップで終了
# 97エピソード: 122ステップで終了
# 98エピソード: 113ステップで終了
# 99エピソード: 171ステップで終了
# 100エピソード: 200ステップで終了
# 101エピソード: 124ステップで終了
# 102エピソード: 110ステップで終了
# 103エピソード: 182ステップで終了
# 104エピソード: 101ステップで終了
# 105エピソード: 94ステップで終了
# 106エピソード: 77ステップで終了
# 107エピソード: 17ステップで終了
# 108エピソード: 200ステップで終了
# 109エピソード: 175ステップで終了
# 110エピソード: 181ステップで終了
# 111エピソード: 167ステップで終了
# 112エピソード: 153ステップで終了
# 113エピソード: 103ステップで終了
# 114エピソード: 130ステップで終了
# 115エピソード: 169ステップで終了
# 116エピソード: 88ステップで終了
# 117エピソード: 61ステップで終了
# 118エピソード: 200ステップで終了
# 119エピソード: 112ステップで終了
# 120エピソード: 52ステップで終了
# 121エピソード: 49ステップで終了
# 122エピソード: 45ステップで終了
# 123エピソード: 14ステップで終了
# 124エピソード: 148ステップで終了
# 125エピソード: 200ステップで終了
# 126エピソード: 46ステップで終了
# 127エピソード: 158ステップで終了
# 128エピソード: 145ステップで終了
# 129エピソード: 57ステップで終了
# 130エピソード: 189ステップで終了
# 131エピソード: 25ステップで終了
# 132エピソード: 32ステップで終了
# 133エピソード: 192ステップで終了
# 134エピソード: 200ステップで終了
# 135エピソード: 23ステップで終了
# 136エピソード: 19ステップで終了
# 137エピソード: 9ステップで終了
# 138エピソード: 11ステップで終了
# 139エピソード: 25ステップで終了
# 140エピソード: 119ステップで終了
# 141エピソード: 176ステップで終了
# 142エピソード: 131ステップで終了
# 143エピソード: 137ステップで終了
# 144エピソード: 128ステップで終了
# 145エピソード: 156ステップで終了
# 146エピソード: 200ステップで終了
# 147エピソード: 143ステップで終了
# 148エピソード: 75ステップで終了
# 149エピソード: 166ステップで終了
# 150エピソード: 200ステップで終了
# 151エピソード: 200ステップで終了
# 152エピソード: 144ステップで終了
# 153エピソード: 169ステップで終了
# 154エピソード: 162ステップで終了
# 155エピソード: 50ステップで終了
# 156エピソード: 99ステップで終了
# 157エピソード: 126ステップで終了
# 158エピソード: 42ステップで終了
# 159エピソード: 113ステップで終了
# 160エピソード: 182ステップで終了
# 161エピソード: 152ステップで終了
# 162エピソード: 186ステップで終了
# 163エピソード: 80ステップで終了
# 164エピソード: 119ステップで終了
# 165エピソード: 161ステップで終了
# 166エピソード: 200ステップで終了
# 167エピソード: 200ステップで終了
# 168エピソード: 200ステップで終了
# 169エピソード: 191ステップで終了
# 170エピソード: 200ステップで終了
# 171エピソード: 200ステップで終了
# 172エピソード: 200ステップで終了
# 173エピソード: 200ステップで終了
# 174エピソード: 126ステップで終了
# 175エピソード: 200ステップで終了
# 176エピソード: 200ステップで終了
# 177エピソード: 200ステップで終了
# 178エピソード: 200ステップで終了
# 179エピソード: 200ステップで終了
# 180エピソード: 200ステップで終了
# 181エピソード: 200ステップで終了
# 182エピソード: 200ステップで終了
# 183エピソード: 200ステップで終了
# 184エピソード: 200ステップで終了
# 10回連続成功
# 185エピソード: 200ステップで終了
# /home/mb21/.local/share/virtualenvs/ai-design-2-9mOrx4rA/lib/python3.8/site-packages/JSAnimation/html_writer.py:281: MatplotlibDeprecationWarning:
# The 'clear_temp' parameter of setup() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. If any parameter follows 'clear_temp', they should be passed as keyword, not positionally.
#   super(HTMLWriter, self).setup(fig, outfile, dpi,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-135fd70ab5ea> in <module>
#       1 # main
#       2 cartpole_env = Environment()
# ----> 3 cartpole_env.run()
#
# <ipython-input-5-8566c1ff1665> in run(self)
#      56             # 最終エピソードの場合は動画を保存
#      57             if is_episode_final:
# ---> 58                 save_as_gif(frames)
#      59                 break
#      60
#
# <ipython-input-2-afd81d25a2e4> in save_as_gif(frames)
#      14
#      15     anim.save('RL-cartpole.mp4')
# ---> 16     display(display_animation(anim, default_mode='loop'))
#
# ~/.local/share/virtualenvs/ai-design-2-9mOrx4rA/lib/python3.8/site-packages/JSAnimation/IPython_display.py in display_animation(anim, **kwargs)
#      84     """Display the animation with an IPython HTML object"""
#      85     from IPython.display import HTML
# ---> 86     return HTML(anim_to_html(anim, **kwargs))
#      87
#      88
#
# ~/.local/share/virtualenvs/ai-design-2-9mOrx4rA/lib/python3.8/site-packages/JSAnimation/IPython_display.py in anim_to_html(anim, fps, embed_frames, default_mode)
#      72         #with tempfile.NamedTemporaryFile(suffix='.html') as f:
#      73         with _NameOnlyTemporaryFile(suffix='.html') as f:
# ---> 74             anim.save(f.name,  writer=HTMLWriter(fps=fps,
#      75                                                  embed_frames=embed_frames,
#      76                                                  default_mode=default_mode))
#
# ~/.local/share/virtualenvs/ai-design-2-9mOrx4rA/lib/python3.8/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1143                         progress_callback(frame_number, total_frames)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#    1147     def _step(self, *args):
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# ~/.local/share/virtualenvs/ai-design-2-9mOrx4rA/lib/python3.8/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     251             yield self
#     252         finally:
# --> 253             self.finish()
#     254
#     255
#
# ~/.local/share/virtualenvs/ai-design-2-9mOrx4rA/lib/python3.8/site-packages/matplotlib/animation.py in finish(self)
#     516         # Call run here now that all frame grabbing is done. All temp files
#     517         # are available to be assembled.
# --> 518         self._run()
#     519         MovieWriter.finish(self)  # Will call clean-up
#     520
#
# ~/.local/share/virtualenvs/ai-design-2-9mOrx4rA/lib/python3.8/site-packages/JSAnimation/html_writer.py in _run(self)
#     321             of.write(JS_INCLUDE)
#     322             of.write(DISPLAY_TEMPLATE.format(id=self.new_id(),
# --> 323                                              Nframes=len(self._temp_names),
#     324                                              fill_frames=fill_frames,
#     325                                              interval=interval,
#
# AttributeError: 'HTMLWriter' object has no attribute '_temp_names'
